# %%
# !pip install gdown >> /dev/null

# %% [markdown]
# # Existing Data (already prepared)
#
# ---

# %% [markdown]
# ## 256x256

# %%
# !gdown 1UUCGWRSMxGNJn5AmwWd3EavpT39Qzxau # 600 peer samples
# !gdown 1AqvKd52QWZt8abG9oZoGYDc6XlfPueCP # 1000 peer samples train
# !gdown 1nF5y47OrLXnfq0lyXmwyU0IAQEdv5ZWu # 150 peer samples
# Out:
# object address  : 0x7c17d312bb80
# object refcount : 2
# object type     : 0x9d5ea0
# object type name: KeyboardInterrupt
# object repr     : KeyboardInterrupt()
# lost sys.stderr
# ^C
# Downloading...
# From (original): https://drive.google.com/uc?id=1nF5y47OrLXnfq0lyXmwyU0IAQEdv5ZWu
# From (redirected): https://drive.google.com/uc?id=1nF5y47OrLXnfq0lyXmwyU0IAQEdv5ZWu&confirm=t&uuid=574b030c-ab5c-43f1-983b-96b3d936580b
# To: /content/val.zip
# 100% 186M/186M [00:04<00:00, 44.9MB/s]

# %%
# !unzip train >> /dev/null
# !unzip val >> /dev/null

# %%
# !git clone https://github.com/ucef-b/agri-data.git
# !cp -r agri-data/* .
# Out:
# fatal: destination path 'agri-data' already exists and is not an empty directory.

# %% [markdown]
# # Train the models

# %% [markdown]
# ## Train on 256x256 (Resized from 512x512 Patches)

# %%
import tensorflow as tf

gpu_available = tf.config.list_physical_devices('GPU')

if gpu_available:
  print("GPU is available")
else:
  print("GPU not available")
# Out:
# GPU is available

# %%
import numpy as np
from pathlib import Path
from typing import Tuple, Dict, List, Optional, Union
import random
from keras import layers, Model
import tensorflow.keras.applications as keras_applications

# %% [markdown]
# Test load

# %%
from DataLoader import DatasetLoader

train_datasets = DatasetLoader(
    working_path="val",
    batch_size=16,
    export_type="NDVI",
    outputs_type="both",
    shuffle=True
)

for x_batch, y_batch in train_datasets:
    print("Input batch shape:", x_batch.shape)
    print("Segmentation output batch shape:", y_batch['segmentation_output'].shape)
    print("Classification output batch shape:", y_batch['classification_output'].shape)
    break
# Out:
# Input batch shape: (16, 512, 512, 1)
# Segmentation output batch shape: (16, 512, 512, 1)
# Classification output batch shape: (16, 6)

# %% [markdown]
# Generate datasets for training

# %%
def create_datasets(working_path: str, batch_size: int, export_type: str, input_shape) -> Tuple[tf.data.Dataset, tf.data.Dataset]:

    num_classes = 6
    if input_shape is None:
            # export_type
            segmentation_output_shape = (256, 256, 1)
            if export_type == "NDVI":
                input_shape = (256, 256, 1)
            elif export_type == "RGB":
                input_shape = (256, 256, 3)
            elif export_type == "RGBN":
                input_shape = (256, 256, 4)

            else:
                raise ValueError(f"Unsupported export_type: {export_type}. Choose from 'NDVI', 'RGB', 'RGBN'.")
    else :
        segmentation_output_shape = (input_shape[0], input_shape[1], 1)

    train_loader = DatasetLoader(
        working_path=f"{working_path}/train",
        batch_size=batch_size,
        export_type=export_type,
        outputs_type="both",
        shuffle=True
    )

    val_loader = DatasetLoader(
        working_path=f"{working_path}/val",
        batch_size=batch_size,
        export_type=export_type,
        outputs_type="both",
        shuffle=False
    )

    def train_generator_fn():
        for batch_x, batch_y in train_loader:
            # scale pixel values to [0, 1]
            yield batch_x.astype(np.float32) / 255.0, batch_y

    def val_generator_fn():
        for batch_x, batch_y in val_loader:
             # scale pixel values to [0, 1]
            yield batch_x.astype(np.float32) / 255.0, batch_y

    output_signature = (
        tf.TensorSpec((None, *input_shape), tf.float32),
        {
            'segmentation_output':    tf.TensorSpec((None, *segmentation_output_shape), tf.float32),
            'classification_output':  tf.TensorSpec((None, num_classes), tf.float32),
        }
    )

    train_dataset = tf.data.Dataset.from_generator(
        train_generator_fn,
        output_signature=output_signature,
    ).prefetch(tf.data.AUTOTUNE)

    val_dataset = tf.data.Dataset.from_generator(
        val_generator_fn,
        output_signature=output_signature,
    ).prefetch(tf.data.AUTOTUNE)

    return train_dataset, val_dataset

train_dataset, val_dataset = create_datasets(working_path=".", batch_size=32, export_type="NDVI", input_shape=(256, 256, 1))

# %% [markdown]
# Define loss

# %%
def binary_dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)

def binary_dice_loss(y_true, y_pred):

    return 1 - binary_dice_coefficient(y_true, y_pred)

def weighted_binary_crossentropy(pos_weight=1.0):
    def loss(y_true, y_pred):
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)

        pos_loss = pos_weight * y_true * tf.math.log(y_pred)
        neg_loss = (1 - y_true) * tf.math.log(1 - y_pred)

        return -tf.reduce_mean(pos_loss + neg_loss)
    return loss
def combined_segmentation_loss(pos_weight=2.0):

    bce = weighted_binary_crossentropy(pos_weight)

    def loss(y_true, y_pred):
        return bce(y_true, y_pred) + binary_dice_loss(y_true, y_pred)

    return loss

# %% [markdown]
# Multitask model (lightweight)

# %%
def separable_residual_block(input_tensor, num_filters, kernel_size=3):
    """Lightweight residual block using separable convolutions"""
    x = layers.SeparableConv2D(num_filters, (kernel_size, kernel_size), padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.SeparableConv2D(num_filters, (kernel_size, kernel_size), padding='same')(x)
    x = layers.BatchNormalization()(x)

    # Skip connection with 1x1 conv if needed
    if input_tensor.shape[-1] != num_filters:
        input_tensor = layers.Conv2D(num_filters, (1, 1))(input_tensor)

    x = layers.add([x, input_tensor])
    x = layers.Activation('relu')(x)
    return x

def lite_encoder_block(input_tensor, num_filters, dropout_rate=0.1):
    """Lightweight encoder block"""
    x = layers.SeparableConv2D(num_filters, (3, 3), padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    if dropout_rate > 0:
        x = layers.SpatialDropout2D(dropout_rate)(x)

    p = layers.MaxPooling2D((2, 2))(x)
    return x, p

def lite_decoder_block(input_tensor, skip_features, num_filters, dropout_rate=0.1):
    """Lightweight decoder block"""
    x = layers.Conv2DTranspose(num_filters, (3, 3), strides=(2, 2), padding='same')(input_tensor)

    # Ensure compatible shapes for concatenation
    if x.shape[1] != skip_features.shape[1] or x.shape[2] != skip_features.shape[2]:
        x = layers.Resizing(skip_features.shape[1], skip_features.shape[2])(x)

    # Concatenate skip features
    x = layers.concatenate([x, skip_features], axis=-1)

    # Reduce parameter count with separable convolution
    x = layers.SeparableConv2D(num_filters, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    if dropout_rate > 0:
        x = layers.SpatialDropout2D(dropout_rate)(x)
    return x

def build_optimized_multi_task_unet(
    input_shape,
    num_classes,
    filters_base=24,
    dropout_rate=0.1,
    final_activation='sigmoid'
):
    # Input layer
    inputs = layers.Input(shape=input_shape)

    # Initial convolution - using standard conv for better feature extraction at start
    x = layers.Conv2D(filters_base, (3, 3), padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    # Encoder Path - with reduced parameters
    s1, p1 = lite_encoder_block(x, filters_base, dropout_rate)
    s2, p2 = lite_encoder_block(p1, filters_base*2, dropout_rate)
    s3, p3 = lite_encoder_block(p2, filters_base*4, dropout_rate)
    s4, p4 = lite_encoder_block(p3, filters_base*8, dropout_rate)

    # Bottleneck - use separable residual block for performance
    bottleneck = separable_residual_block(p4, filters_base*16)
    bottleneck = layers.SpatialDropout2D(dropout_rate*2)(bottleneck)

    # Decoder Path for Segmentation
    d1 = lite_decoder_block(bottleneck, s4, filters_base*8, dropout_rate)
    d2 = lite_decoder_block(d1, s3, filters_base*4, dropout_rate)
    d3 = lite_decoder_block(d2, s2, filters_base*2, dropout_rate)
    d4 = lite_decoder_block(d3, s1, filters_base, dropout_rate)

    # Segmentation Output
    segmentation_output = layers.Conv2D(1, (1, 1))(d4)
    segmentation_output = layers.Activation(final_activation, name='segmentation_output')(segmentation_output)

    avg_pool = layers.GlobalAveragePooling2D()(bottleneck)
    max_pool = layers.GlobalMaxPooling2D()(bottleneck)
    pooled_features = layers.concatenate([avg_pool, max_pool])

    # Streamlined classification head
    classification_branch = layers.Dense(128)(pooled_features)
    classification_branch = layers.BatchNormalization()(classification_branch)
    classification_branch = layers.Activation('relu')(classification_branch)
    classification_branch = layers.Dropout(0.2)(classification_branch)

    # Classification Output
    classification_output = layers.Dense(num_classes, activation='softmax', name='classification_output')(classification_branch)

    # Create model with multiple outputs
    model = Model(inputs=inputs, outputs=[segmentation_output, classification_output], name='Optimized_MultiTask_UNet')

    return model

def compile_model(model):
    """Compile the model with appropriate losses and metrics"""
    losses = {
        'segmentation_output': 'binary_crossentropy',
        'classification_output': 'binary_crossentropy'
    }

    loss_weights = {
        'segmentation_output': 1.0,
        'classification_output': 0.5
    }

    metrics = {
        'segmentation_output': ['accuracy', binary_dice_coefficient ],
        'classification_output': ['accuracy']
    }

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss=losses,
        loss_weights=loss_weights,
        metrics=metrics
    )

    return model

# %%
train_dataset, val_dataset = create_datasets(working_path=".", batch_size=32, export_type="RGB")
input_shape = (256, 256, 3) # ndvi rgb rgbn
num_classes = 6



optimized_model = build_optimized_multi_task_unet(input_shape, num_classes)
optimized_model = compile_model(optimized_model)
optimized_model.summary()
# Out:
# Model: "Optimized_MultiTask_UNet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_7       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 256, 256,  │        672 │ input_layer_7[0]… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         96 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_76       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_64 │ (None, 256, 256,  │        816 │ activation_76[0]… │
# │ (SeparableConv2D)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         96 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_77       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_… │ (None, 256, 256,  │          0 │ activation_77[0]… │
# │ (SpatialDropout2D)  │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_20    │ (None, 128, 128,  │          0 │ spatial_dropout2… │
# │ (MaxPooling2D)      │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_65 │ (None, 128, 128,  │      1,416 │ max_pooling2d_20… │
# │ (SeparableConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        192 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_78       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_… │ (None, 128, 128,  │          0 │ activation_78[0]… │
# │ (SpatialDropout2D)  │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_21    │ (None, 64, 64,    │          0 │ spatial_dropout2… │
# │ (MaxPooling2D)      │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_66 │ (None, 64, 64,    │      5,136 │ max_pooling2d_21… │
# │ (SeparableConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        384 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_79       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_… │ (None, 64, 64,    │          0 │ activation_79[0]… │
# │ (SpatialDropout2D)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_22    │ (None, 32, 32,    │          0 │ spatial_dropout2… │
# │ (MaxPooling2D)      │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_67 │ (None, 32, 32,    │     19,488 │ max_pooling2d_22… │
# │ (SeparableConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        768 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_80       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_… │ (None, 32, 32,    │          0 │ activation_80[0]… │
# │ (SpatialDropout2D)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_23    │ (None, 16, 16,    │          0 │ spatial_dropout2… │
# │ (MaxPooling2D)      │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_68 │ (None, 16, 16,    │     75,840 │ max_pooling2d_23… │
# │ (SeparableConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,536 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_81       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_69 │ (None, 16, 16,    │    151,296 │ activation_81[0]… │
# │ (SeparableConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,536 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 16, 16,    │     74,112 │ max_pooling2d_23… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 384)              │            │ conv2d_20[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_82       │ (None, 16, 16,    │          0 │ add_7[0][0]       │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_… │ (None, 16, 16,    │          0 │ activation_82[0]… │
# │ (SpatialDropout2D)  │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_30 │ (None, 32, 32,    │    663,744 │ spatial_dropout2… │
# │ (Conv2DTranspose)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_37      │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 384)              │            │ spatial_dropout2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_70 │ (None, 32, 32,    │     77,376 │ concatenate_37[0… │
# │ (SeparableConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        768 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_83       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_… │ (None, 32, 32,    │          0 │ activation_83[0]… │
# │ (SpatialDropout2D)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_31 │ (None, 64, 64,    │    165,984 │ spatial_dropout2… │
# │ (Conv2DTranspose)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_38      │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 192)              │            │ spatial_dropout2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_71 │ (None, 64, 64,    │     20,256 │ concatenate_38[0… │
# │ (SeparableConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        384 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_84       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_… │ (None, 64, 64,    │          0 │ activation_84[0]… │
# │ (SpatialDropout2D)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_32 │ (None, 128, 128,  │     41,520 │ spatial_dropout2… │
# │ (Conv2DTranspose)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_39      │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 96)               │            │ spatial_dropout2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_72 │ (None, 128, 128,  │      5,520 │ concatenate_39[0… │
# │ (SeparableConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        192 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_85       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_… │ (None, 128, 128,  │          0 │ activation_85[0]… │
# │ (SpatialDropout2D)  │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_33 │ (None, 256, 256,  │     10,392 │ spatial_dropout2… │
# │ (Conv2DTranspose)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_40      │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 48)               │            │ spatial_dropout2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 384)       │          0 │ spatial_dropout2… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 384)       │          0 │ spatial_dropout2… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_73 │ (None, 256, 256,  │      1,608 │ concatenate_40[0… │
# │ (SeparableConv2D)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_41      │ (None, 768)       │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         96 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 128)       │     98,432 │ concatenate_41[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_86       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_7[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_… │ (None, 256, 256,  │          0 │ activation_86[0]… │
# │ (SpatialDropout2D)  │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_87       │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 256, 256,  │         25 │ spatial_dropout2… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 128)       │          0 │ activation_87[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ segmentation_output │ (None, 256, 256,  │          0 │ conv2d_21[0][0]   │
# │ (Activation)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classification_out… │ (None, 6)         │        774 │ dropout_7[0][0]   │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,420,967 (5.42 MB)
#  Trainable params: 1,417,687 (5.41 MB)
#  Non-trainable params: 3,280 (12.81 KB)

# %%
h = optimized_model.fit(train_dataset, epochs=20)
# Out:
# Epoch 1/20
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 134s 347ms/step - classification_output_accuracy: 0.2163 - classification_output_loss: 0.5734 - loss: 0.9181 - segmentation_output_accuracy: 0.6599 - segmentation_output_binary_dice_coefficient: 0.2869 - segmentation_output_loss: 0.6314
# Epoch 2/20
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 53s 265ms/step - classification_output_accuracy: 0.4513 - classification_output_loss: 0.3814 - loss: 0.7310 - segmentation_output_accuracy: 0.7596 - segmentation_output_binary_dice_coefficient: 0.2650 - segmentation_output_loss: 0.5403
# Epoch 3/20
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 82s 265ms/step - classification_output_accuracy: 0.5327 - classification_output_loss: 0.3343 - loss: 0.6830 - segmentation_output_accuracy: 0.7706 - segmentation_output_binary_dice_coefficient: 0.2775 - segmentation_output_loss: 0.5159
# Epoch 4/20
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 82s 265ms/step - classification_output_accuracy: 0.5614 - classification_output_loss: 0.3157 - loss: 0.6722 - segmentation_output_accuracy: 0.7683 - segmentation_output_binary_dice_coefficient: 0.2898 - segmentation_output_loss: 0.5143
# Epoch 5/20
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 48s 263ms/step - classification_output_accuracy: 0.5779 - classification_output_loss: 0.3040 - loss: 0.6605 - segmentation_output_accuracy: 0.7716 - segmentation_output_binary_dice_coefficient: 0.2973 - segmentation_output_loss: 0.5085
# Epoch 6/20
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 48s 264ms/step - classification_output_accuracy: 0.6022 - classification_output_loss: 0.2909 - loss: 0.6444 - segmentation_output_accuracy: 0.7784 - segmentation_output_binary_dice_coefficient: 0.3049 - segmentation_output_loss: 0.4989
# Epoch 7/20
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 48s 263ms/step - classification_output_accuracy: 0.6231 - classification_output_loss: 0.2783 - loss: 0.6434 - segmentation_output_accuracy: 0.7752 - segmentation_output_binary_dice_coefficient: 0.3140 - segmentation_output_loss: 0.5043
# Epoch 8/20
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 48s 263ms/step - classification_output_accuracy: 0.6208 - classification_output_loss: 0.2769 - loss: 0.6378 - segmentation_output_accuracy: 0.7786 - segmentation_output_binary_dice_coefficient: 0.3214 - segmentation_output_loss: 0.4993
# Epoch 9/20
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 82s 265ms/step - classification_output_accuracy: 0.6371 - classification_output_loss: 0.2667 - loss: 0.6350 - segmentation_output_accuracy: 0.7767 - segmentation_output_binary_dice_coefficient: 0.3204 - segmentation_output_loss: 0.5016
# Epoch 10/20
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 48s 261ms/step - classification_output_accuracy: 0.6610 - classification_output_loss: 0.2536 - loss: 0.6146 - segmentation_output_accuracy: 0.7837 - segmentation_output_binary_dice_coefficient: 0.3264 - segmentation_output_loss: 0.4878
# Epoch 11/20
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 48s 264ms/step - classification_output_accuracy: 0.6526 - classification_output_loss: 0.2582 - loss: 0.6071 - segmentation_output_accuracy: 0.7904 - segmentation_output_binary_dice_coefficient: 0.3308 - segmentation_output_loss: 0.4780
# Epoch 12/20
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 48s 262ms/step - classification_output_accuracy: 0.6652 - classification_output_loss: 0.2485 - loss: 0.6059 - segmentation_output_accuracy: 0.7859 - segmentation_output_binary_dice_coefficient: 0.3379 - segmentation_output_loss: 0.4817
# Epoch 13/20
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 48s 263ms/step - classification_output_accuracy: 0.6813 - classification_output_loss: 0.2405 - loss: 0.5978 - segmentation_output_accuracy: 0.7868 - segmentation_output_binary_dice_coefficient: 0.3496 - segmentation_output_loss: 0.4775
# Epoch 14/20
#  63/183 ━━━━━━━━━━━━━━━━━━━━ 35s 293ms/step - classification_output_accuracy: 0.6808 - classification_output_loss: 0.2401 - loss: 0.6071 - segmentation_output_accuracy: 0.7813 - segmentation_output_binary_dice_coefficient: 0.3477 - segmentation_output_loss: 0.4871

# %%
h1 = optimized_model.fit(train_dataset, epochs=20)

# %%
optimized_model.evaluate(val_dataset)
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 15s 431ms/step - classification_output_accuracy: 0.6541 - classification_output_loss: 0.2634 - loss: 0.6572 - segmentation_output_accuracy: 0.7480 - segmentation_output_binary_dice_coefficient: 0.3725 - segmentation_output_loss: 0.5253
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# [0.6339068412780762,
#  0.4951084554195404,
#  0.2711845338344574,
#  0.6313363909721375,
#  0.7683383226394653,
#  0.3487536311149597]

# %%
def separable_residual_block(input_tensor, num_filters, kernel_size=3):
    """Lightweight residual block using separable convolutions"""
    x = layers.SeparableConv2D(num_filters, (kernel_size, kernel_size), padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.SeparableConv2D(num_filters, (kernel_size, kernel_size), padding='same')(x)
    x = layers.BatchNormalization()(x)

    # Skip connection with 1x1 conv if needed
    if input_tensor.shape[-1] != num_filters:
        input_tensor = layers.Conv2D(num_filters, (1, 1))(input_tensor)

    x = layers.add([x, input_tensor])
    x = layers.Activation('relu')(x)
    return x

def lite_encoder_block(input_tensor, num_filters, dropout_rate=0.1):
    """Lightweight encoder block"""
    x = layers.SeparableConv2D(num_filters, (3, 3), padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    if dropout_rate > 0:
        x = layers.SpatialDropout2D(dropout_rate)(x)

    p = layers.MaxPooling2D((2, 2))(x)
    return x, p

def lite_decoder_block(input_tensor, skip_features, num_filters, dropout_rate=0.1):
    """Lightweight decoder block"""
    x = layers.Conv2DTranspose(num_filters, (3, 3), strides=(2, 2), padding='same')(input_tensor)

    # Ensure compatible shapes for concatenation
    if x.shape[1] != skip_features.shape[1] or x.shape[2] != skip_features.shape[2]:
        x = layers.Resizing(skip_features.shape[1], skip_features.shape[2])(x)

    # Concatenate skip features
    x = layers.concatenate([x, skip_features], axis=-1)

    # Reduce parameter count with separable convolution
    x = layers.SeparableConv2D(num_filters, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    if dropout_rate > 0:
        x = layers.SpatialDropout2D(dropout_rate)(x)
    return x

def binary_dice_coefficient(y_true, y_pred):
    """Binary Dice coefficient metric"""
    smooth = 1.0
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + smooth)


def get_backbone(backbone_name, input_tensor, weights='imagenet', trainable=False):
    backbone_dict = {
        'mobilenetv2': {
            'model': keras_applications.MobileNetV2,
            'skip_layers': ['block_13_expand_relu', 'block_6_expand_relu',
                           'block_3_expand_relu', 'block_1_expand_relu'] # Ordered from deeper to shallower
        }
    }

    if backbone_name.lower() not in backbone_dict:
        raise ValueError(f"Backbone {backbone_name} not supported. Choose from: {list(backbone_dict.keys())}")

    backbone_fn = backbone_dict[backbone_name.lower()]['model']
    skip_layer_names = backbone_dict[backbone_name.lower()]['skip_layers']

    backbone = backbone_fn(
        include_top=False,
        weights=weights,
        input_tensor=input_tensor,
        input_shape=None if input_tensor is not None else input_tensor.shape[1:]
    )

    backbone.trainable = trainable

    skip_connections = [backbone.get_layer(layer_name).output for layer_name in skip_layer_names]

    initial_features = input_tensor # Using the input tensor

    return backbone, skip_connections, initial_features

def build_backbone_multi_task_unet(
    input_shape,
    num_classes,
    backbone_name='mobilenetv2',
    backbone_trainable=False,
    filters_base=24,
    dropout_rate=0.1,
    final_activation='sigmoid' # Changed to sigmoid for binary crossentropy
):
    inputs = layers.Input(shape=input_shape)

    backbone, skip_features, initial_features = get_backbone(
        backbone_name=backbone_name,
        input_tensor=inputs,
        trainable=backbone_trainable
    )

    bottleneck = backbone.output

    bottleneck = separable_residual_block(bottleneck, filters_base*16)
    bottleneck = layers.SpatialDropout2D(dropout_rate*2)(bottleneck)

    d1 = lite_decoder_block(bottleneck, skip_features[0], filters_base*8, dropout_rate) # connect with 16x16 skip
    d2 = lite_decoder_block(d1, skip_features[1], filters_base*4, dropout_rate)         # connect with 32x32 skip
    d3 = lite_decoder_block(d2, skip_features[2], filters_base*2, dropout_rate)         # connect with 64x64 skip
    d4 = lite_decoder_block(d3, skip_features[3], filters_base, dropout_rate)           # connect with 128x128 skip

    # add one more decoder block to upsample to 256x256, connecting with initial features
    d5 = lite_decoder_block(d4, initial_features, filters_base, dropout_rate)           # connect with 256x256 skip (input)


    # Segmentation Output
    segmentation_output = layers.Conv2D(1, (1, 1))(d5) # Apply conv to the final decoder output
    segmentation_output = layers.Activation(final_activation, name='segmentation_output')(segmentation_output)

    # Classification branch from bottleneck
    avg_pool = layers.GlobalAveragePooling2D()(bottleneck)
    max_pool = layers.GlobalMaxPooling2D()(bottleneck)
    pooled_features = layers.concatenate([avg_pool, max_pool])

    # Streamlined classification head
    classification_branch = layers.Dense(128)(pooled_features)
    classification_branch = layers.BatchNormalization()(classification_branch)
    classification_branch = layers.Activation('relu')(classification_branch)
    classification_branch = layers.Dropout(0.2)(classification_branch)

    # Classification Output
    classification_output = layers.Dense(num_classes, activation='softmax', name='classification_output')(classification_branch)


    # Create model with multiple outputs
    model = Model(inputs=inputs, outputs=[segmentation_output, classification_output],
                 name=f'Backbone_MultiTask_UNet_{backbone_name}')

    return model

def compile_model(model):
    """Compile the model with appropriate losses and metrics"""
    losses = {
        'segmentation_output': 'binary_crossentropy',
        'classification_output': 'binary_crossentropy'
    }

    loss_weights = {
        'segmentation_output': 1.0,
        'classification_output': 0.5
    }

    metrics = {
        'segmentation_output': ['accuracy', binary_dice_coefficient],
        'classification_output': ['accuracy']
    }

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss=losses,
        loss_weights=loss_weights,
        metrics=metrics
    )

    return model

input_shape = (256, 256, 3)
num_classes = 6

backbone_model = build_backbone_multi_task_unet(
    input_shape,
    num_classes,
    backbone_name='mobilenetv2',
    backbone_trainable=False,
    final_activation='sigmoid'
)
backbone_model = compile_model(backbone_model)
backbone_model.summary()
# Out:
# <ipython-input-30-a1c21e63afbc>:90: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   backbone = backbone_fn(
# Model: "Backbone_MultiTask_UNet_mobilenetv2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 128, 128,  │        864 │ input_layer_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 128, 128,  │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 128, 128,  │          0 │ bn_Conv1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 128, 128,  │        288 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 128, 128,  │        128 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 128, 128,  │          0 │ expanded_conv_de… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 128, 128,  │        512 │ expanded_conv_de… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 128, 128,  │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 128, 128,  │      1,536 │ expanded_conv_pr… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 128, 128,  │        384 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 128, 128,  │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 129, 129,  │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 64, 64,    │        864 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 64, 64,    │        384 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 64, 64,    │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 64, 64,    │      2,304 │ block_1_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 64, 64,    │         96 │ block_1_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 64, 64,    │      3,456 │ block_1_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 64, 64,    │        576 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 64, 64,    │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 64, 64,    │      1,296 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 64, 64,    │        576 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 64, 64,    │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 64, 64,    │      3,456 │ block_2_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 64, 64,    │         96 │ block_2_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 64, 64,    │          0 │ block_1_project_… │
# │                     │ 24)               │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 64, 64,    │      3,456 │ block_2_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 64, 64,    │        576 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 64, 64,    │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 65, 65,    │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 32, 32,    │      1,296 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 32, 32,    │        576 │ block_3_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 32, 32,    │          0 │ block_3_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 32, 32,    │      4,608 │ block_3_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 32, 32,    │        128 │ block_3_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 32, 32,    │      6,144 │ block_3_project_… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 32, 32,    │        768 │ block_4_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 32, 32,    │          0 │ block_4_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 32, 32,    │      1,728 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 32, 32,    │        768 │ block_4_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 32, 32,    │          0 │ block_4_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 32, 32,    │      6,144 │ block_4_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 32, 32,    │        128 │ block_4_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 32, 32,    │          0 │ block_3_project_… │
# │                     │ 32)               │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 32, 32,    │      6,144 │ block_4_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 32, 32,    │        768 │ block_5_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 32, 32,    │          0 │ block_5_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 32, 32,    │      1,728 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 32, 32,    │        768 │ block_5_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 32, 32,    │          0 │ block_5_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 32, 32,    │      6,144 │ block_5_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 32, 32,    │        128 │ block_5_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None, 32, 32,    │          0 │ block_4_add[0][0… │
# │                     │ 32)               │            │ block_5_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand      │ (None, 32, 32,    │      6,144 │ block_5_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_BN   │ (None, 32, 32,    │        768 │ block_6_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_relu │ (None, 32, 32,    │          0 │ block_6_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_pad         │ (None, 33, 33,    │          0 │ block_6_expand_r… │
# │ (ZeroPadding2D)     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise   │ (None, 16, 16,    │      1,728 │ block_6_pad[0][0] │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 16, 16,    │        768 │ block_6_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 16, 16,    │          0 │ block_6_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project     │ (None, 16, 16,    │     12,288 │ block_6_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project_BN  │ (None, 16, 16,    │        256 │ block_6_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand      │ (None, 16, 16,    │     24,576 │ block_6_project_… │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_BN   │ (None, 16, 16,    │      1,536 │ block_7_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_relu │ (None, 16, 16,    │          0 │ block_7_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise   │ (None, 16, 16,    │      3,456 │ block_7_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 16, 16,    │      1,536 │ block_7_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 16, 16,    │          0 │ block_7_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project     │ (None, 16, 16,    │     24,576 │ block_7_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project_BN  │ (None, 16, 16,    │        256 │ block_7_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_add (Add)   │ (None, 16, 16,    │          0 │ block_6_project_… │
# │                     │ 64)               │            │ block_7_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand      │ (None, 16, 16,    │     24,576 │ block_7_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_BN   │ (None, 16, 16,    │      1,536 │ block_8_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_relu │ (None, 16, 16,    │          0 │ block_8_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise   │ (None, 16, 16,    │      3,456 │ block_8_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 16, 16,    │      1,536 │ block_8_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 16, 16,    │          0 │ block_8_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project     │ (None, 16, 16,    │     24,576 │ block_8_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project_BN  │ (None, 16, 16,    │        256 │ block_8_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_add (Add)   │ (None, 16, 16,    │          0 │ block_7_add[0][0… │
# │                     │ 64)               │            │ block_8_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand      │ (None, 16, 16,    │     24,576 │ block_8_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_BN   │ (None, 16, 16,    │      1,536 │ block_9_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_relu │ (None, 16, 16,    │          0 │ block_9_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise   │ (None, 16, 16,    │      3,456 │ block_9_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 16, 16,    │      1,536 │ block_9_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 16, 16,    │          0 │ block_9_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project     │ (None, 16, 16,    │     24,576 │ block_9_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project_BN  │ (None, 16, 16,    │        256 │ block_9_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_add (Add)   │ (None, 16, 16,    │          0 │ block_8_add[0][0… │
# │                     │ 64)               │            │ block_9_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand     │ (None, 16, 16,    │     24,576 │ block_9_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_BN  │ (None, 16, 16,    │      1,536 │ block_10_expand[… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_re… │ (None, 16, 16,    │          0 │ block_10_expand_… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise  │ (None, 16, 16,    │      3,456 │ block_10_expand_… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 16, 16,    │      1,536 │ block_10_depthwi… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 16, 16,    │          0 │ block_10_depthwi… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project    │ (None, 16, 16,    │     36,864 │ block_10_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project_BN │ (None, 16, 16,    │        384 │ block_10_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand     │ (None, 16, 16,    │     55,296 │ block_10_project… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_BN  │ (None, 16, 16,    │      2,304 │ block_11_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_re… │ (None, 16, 16,    │          0 │ block_11_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise  │ (None, 16, 16,    │      5,184 │ block_11_expand_… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 16, 16,    │      2,304 │ block_11_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 16, 16,    │          0 │ block_11_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project    │ (None, 16, 16,    │     55,296 │ block_11_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project_BN │ (None, 16, 16,    │        384 │ block_11_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_add (Add)  │ (None, 16, 16,    │          0 │ block_10_project… │
# │                     │ 96)               │            │ block_11_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand     │ (None, 16, 16,    │     55,296 │ block_11_add[0][… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_BN  │ (None, 16, 16,    │      2,304 │ block_12_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_re… │ (None, 16, 16,    │          0 │ block_12_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise  │ (None, 16, 16,    │      5,184 │ block_12_expand_… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 16, 16,    │      2,304 │ block_12_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 16, 16,    │          0 │ block_12_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project    │ (None, 16, 16,    │     55,296 │ block_12_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project_BN │ (None, 16, 16,    │        384 │ block_12_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_add (Add)  │ (None, 16, 16,    │          0 │ block_11_add[0][… │
# │                     │ 96)               │            │ block_12_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand     │ (None, 16, 16,    │     55,296 │ block_12_add[0][… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_BN  │ (None, 16, 16,    │      2,304 │ block_13_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_re… │ (None, 16, 16,    │          0 │ block_13_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_pad        │ (None, 17, 17,    │          0 │ block_13_expand_… │
# │ (ZeroPadding2D)     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise  │ (None, 8, 8, 576) │      5,184 │ block_13_pad[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 8, 8, 576) │      2,304 │ block_13_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 8, 8, 576) │          0 │ block_13_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project    │ (None, 8, 8, 160) │     92,160 │ block_13_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project_BN │ (None, 8, 8, 160) │        640 │ block_13_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand     │ (None, 8, 8, 960) │    153,600 │ block_13_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_BN  │ (None, 8, 8, 960) │      3,840 │ block_14_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_re… │ (None, 8, 8, 960) │          0 │ block_14_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise  │ (None, 8, 8, 960) │      8,640 │ block_14_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 8, 8, 960) │      3,840 │ block_14_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 8, 8, 960) │          0 │ block_14_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project    │ (None, 8, 8, 160) │    153,600 │ block_14_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project_BN │ (None, 8, 8, 160) │        640 │ block_14_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_add (Add)  │ (None, 8, 8, 160) │          0 │ block_13_project… │
# │                     │                   │            │ block_14_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand     │ (None, 8, 8, 960) │    153,600 │ block_14_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_BN  │ (None, 8, 8, 960) │      3,840 │ block_15_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_re… │ (None, 8, 8, 960) │          0 │ block_15_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise  │ (None, 8, 8, 960) │      8,640 │ block_15_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 8, 8, 960) │      3,840 │ block_15_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 8, 8, 960) │          0 │ block_15_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project    │ (None, 8, 8, 160) │    153,600 │ block_15_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project_BN │ (None, 8, 8, 160) │        640 │ block_15_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_add (Add)  │ (None, 8, 8, 160) │          0 │ block_14_add[0][… │
# │                     │                   │            │ block_15_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand     │ (None, 8, 8, 960) │    153,600 │ block_15_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_BN  │ (None, 8, 8, 960) │      3,840 │ block_16_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_re… │ (None, 8, 8, 960) │          0 │ block_16_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise  │ (None, 8, 8, 960) │      8,640 │ block_16_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 8, 8, 960) │      3,840 │ block_16_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 8, 8, 960) │          0 │ block_16_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project    │ (None, 8, 8, 320) │    307,200 │ block_16_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project_BN │ (None, 8, 8, 320) │      1,280 │ block_16_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1 (Conv2D)     │ (None, 8, 8,      │    409,600 │ block_16_project… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1_bn           │ (None, 8, 8,      │      5,120 │ Conv_1[0][0]      │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_relu (ReLU)     │ (None, 8, 8,      │          0 │ Conv_1_bn[0][0]   │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_27 │ (None, 8, 8, 384) │    503,424 │ out_relu[0][0]    │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 384) │      1,536 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, 8, 8, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_28 │ (None, 8, 8, 384) │    151,296 │ activation_32[0]… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 384) │      1,536 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 8, 8, 384) │    491,904 │ out_relu[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 8, 8, 384) │          0 │ batch_normalizat… │
# │                     │                   │            │ conv2d_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_33       │ (None, 8, 8, 384) │          0 │ add_3[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_… │ (None, 8, 8, 384) │          0 │ activation_33[0]… │
# │ (SpatialDropout2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_13 │ (None, 16, 16,    │    663,744 │ spatial_dropout2… │
# │ (Conv2DTranspose)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_16      │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 768)              │            │ block_13_expand_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_29 │ (None, 16, 16,    │    154,560 │ concatenate_16[0… │
# │ (SeparableConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        768 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_34       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_… │ (None, 16, 16,    │          0 │ activation_34[0]… │
# │ (SpatialDropout2D)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_14 │ (None, 32, 32,    │    165,984 │ spatial_dropout2… │
# │ (Conv2DTranspose)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_17      │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 288)              │            │ block_6_expand_r… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_30 │ (None, 32, 32,    │     30,336 │ concatenate_17[0… │
# │ (SeparableConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        384 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_35       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_… │ (None, 32, 32,    │          0 │ activation_35[0]… │
# │ (SpatialDropout2D)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_15 │ (None, 64, 64,    │     41,520 │ spatial_dropout2… │
# │ (Conv2DTranspose)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_18      │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 192)              │            │ block_3_expand_r… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_31 │ (None, 64, 64,    │     10,992 │ concatenate_18[0… │
# │ (SeparableConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        192 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_36       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_… │ (None, 64, 64,    │          0 │ activation_36[0]… │
# │ (SpatialDropout2D)  │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_16 │ (None, 128, 128,  │     10,392 │ spatial_dropout2… │
# │ (Conv2DTranspose)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_19      │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 120)              │            │ block_1_expand_r… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_32 │ (None, 128, 128,  │      3,984 │ concatenate_19[0… │
# │ (SeparableConv2D)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         96 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_37       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_… │ (None, 128, 128,  │          0 │ activation_37[0]… │
# │ (SpatialDropout2D)  │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_17 │ (None, 256, 256,  │      5,208 │ spatial_dropout2… │
# │ (Conv2DTranspose)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_20      │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 27)               │            │ input_layer_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 384)       │          0 │ spatial_dropout2… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 384)       │          0 │ spatial_dropout2… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_33 │ (None, 256, 256,  │        915 │ concatenate_20[0… │
# │ (SeparableConv2D)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_21      │ (None, 768)       │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         96 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 128)       │     98,432 │ concatenate_21[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_38       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_3[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_… │ (None, 256, 256,  │          0 │ activation_38[0]… │
# │ (SpatialDropout2D)  │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_39       │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 256, 256,  │         25 │ spatial_dropout2… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 128)       │          0 │ activation_39[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ segmentation_output │ (None, 256, 256,  │          0 │ conv2d_9[0][0]    │
# │ (Activation)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classification_out… │ (None, 6)         │        774 │ dropout_3[0][0]   │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,596,594 (17.53 MB)
#  Trainable params: 2,336,050 (8.91 MB)
#  Non-trainable params: 2,260,544 (8.62 MB)

# %%
input_shape = (256, 256, 3) # ndvi rgb rgbn
num_classes = 6
batch_size = 32

train_dataset, val_dataset = create_datasets(working_path=".", batch_size=32, export_type="RGB")

# %%
backbone_model.fit(train_dataset, epochs=10)
# Out:
# Epoch 1/10
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 82s 304ms/step - classification_output_accuracy: 0.3586 - classification_output_loss: 0.4952 - loss: 0.9462 - segmentation_output_accuracy: 0.5583 - segmentation_output_binary_dice_coefficient: 0.3117 - segmentation_output_loss: 0.6986
# Epoch 2/10
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - classification_output_accuracy: 0.6382 - classification_output_loss: 0.2731 - loss: 0.6206 - segmentation_output_accuracy: 0.7786 - segmentation_output_binary_dice_coefficient: 0.3032 - segmentation_output_loss: 0.4841
# Epoch 3/10
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 38s 205ms/step - classification_output_accuracy: 0.7280 - classification_output_loss: 0.2187 - loss: 0.5751 - segmentation_output_accuracy: 0.7782 - segmentation_output_binary_dice_coefficient: 0.3591 - segmentation_output_loss: 0.4657
# Epoch 4/10
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 40s 217ms/step - classification_output_accuracy: 0.7994 - classification_output_loss: 0.1734 - loss: 0.5194 - segmentation_output_accuracy: 0.7954 - segmentation_output_binary_dice_coefficient: 0.3886 - segmentation_output_loss: 0.4327
# Epoch 5/10
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 38s 207ms/step - classification_output_accuracy: 0.8374 - classification_output_loss: 0.1416 - loss: 0.4945 - segmentation_output_accuracy: 0.7948 - segmentation_output_binary_dice_coefficient: 0.4107 - segmentation_output_loss: 0.4237
# Epoch 6/10
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 38s 209ms/step - classification_output_accuracy: 0.8866 - classification_output_loss: 0.1076 - loss: 0.4610 - segmentation_output_accuracy: 0.8034 - segmentation_output_binary_dice_coefficient: 0.4356 - segmentation_output_loss: 0.4072
# Epoch 7/10
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 37s 203ms/step - classification_output_accuracy: 0.9116 - classification_output_loss: 0.0853 - loss: 0.4300 - segmentation_output_accuracy: 0.8144 - segmentation_output_binary_dice_coefficient: 0.4535 - segmentation_output_loss: 0.3873
# Epoch 8/10
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 40s 218ms/step - classification_output_accuracy: 0.9238 - classification_output_loss: 0.0757 - loss: 0.4099 - segmentation_output_accuracy: 0.8190 - segmentation_output_binary_dice_coefficient: 0.4783 - segmentation_output_loss: 0.3720
# Epoch 9/10
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 41s 219ms/step - classification_output_accuracy: 0.9616 - classification_output_loss: 0.0466 - loss: 0.3737 - segmentation_output_accuracy: 0.8328 - segmentation_output_binary_dice_coefficient: 0.5024 - segmentation_output_loss: 0.3504
# Epoch 10/10
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 39s 210ms/step - classification_output_accuracy: 0.9573 - classification_output_loss: 0.0436 - loss: 0.3583 - segmentation_output_accuracy: 0.8398 - segmentation_output_binary_dice_coefficient: 0.5328 - segmentation_output_loss: 0.3365

# %%
h_with_bn= backbone_model.fit(train_dataset, epochs=40)
# Out:
# Epoch 1/40
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 38s 205ms/step - classification_output_accuracy: 0.9706 - classification_output_loss: 0.0337 - loss: 0.3467 - segmentation_output_accuracy: 0.8417 - segmentation_output_binary_dice_coefficient: 0.5515 - segmentation_output_loss: 0.3298
# Epoch 2/40
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 38s 205ms/step - classification_output_accuracy: 0.9770 - classification_output_loss: 0.0299 - loss: 0.3276 - segmentation_output_accuracy: 0.8535 - segmentation_output_binary_dice_coefficient: 0.5629 - segmentation_output_loss: 0.3126
# Epoch 3/40
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 38s 206ms/step - classification_output_accuracy: 0.9665 - classification_output_loss: 0.0358 - loss: 0.3225 - segmentation_output_accuracy: 0.8580 - segmentation_output_binary_dice_coefficient: 0.5749 - segmentation_output_loss: 0.3046
# Epoch 4/40
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 38s 209ms/step - classification_output_accuracy: 0.9866 - classification_output_loss: 0.0195 - loss: 0.2867 - segmentation_output_accuracy: 0.8719 - segmentation_output_binary_dice_coefficient: 0.6031 - segmentation_output_loss: 0.2770
# Epoch 5/40
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 38s 205ms/step - classification_output_accuracy: 0.9871 - classification_output_loss: 0.0191 - loss: 0.2840 - segmentation_output_accuracy: 0.8733 - segmentation_output_binary_dice_coefficient: 0.6250 - segmentation_output_loss: 0.2745
# Epoch 6/40
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 38s 209ms/step - classification_output_accuracy: 0.9843 - classification_output_loss: 0.0202 - loss: 0.2692 - segmentation_output_accuracy: 0.8828 - segmentation_output_binary_dice_coefficient: 0.6413 - segmentation_output_loss: 0.2590
# Epoch 7/40
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 38s 206ms/step - classification_output_accuracy: 0.9828 - classification_output_loss: 0.0182 - loss: 0.2593 - segmentation_output_accuracy: 0.8874 - segmentation_output_binary_dice_coefficient: 0.6525 - segmentation_output_loss: 0.2502
# Epoch 8/40
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 38s 208ms/step - classification_output_accuracy: 0.9882 - classification_output_loss: 0.0142 - loss: 0.2559 - segmentation_output_accuracy: 0.8882 - segmentation_output_binary_dice_coefficient: 0.6705 - segmentation_output_loss: 0.2488
# Epoch 9/40
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 38s 207ms/step - classification_output_accuracy: 0.9828 - classification_output_loss: 0.0174 - loss: 0.2385 - segmentation_output_accuracy: 0.8999 - segmentation_output_binary_dice_coefficient: 0.6893 - segmentation_output_loss: 0.2298
# Epoch 10/40
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 39s 211ms/step - classification_output_accuracy: 0.9845 - classification_output_loss: 0.0149 - loss: 0.2191 - segmentation_output_accuracy: 0.9079 - segmentation_output_binary_dice_coefficient: 0.7176 - segmentation_output_loss: 0.2117
# Epoch 11/40
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 40s 219ms/step - classification_output_accuracy: 0.9853 - classification_output_loss: 0.0165 - loss: 0.2258 - segmentation_output_accuracy: 0.9064 - segmentation_output_binary_dice_coefficient: 0.7057 - segmentation_output_loss: 0.2176
# Epoch 12/40
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 39s 207ms/step - classification_output_accuracy: 0.9924 - classification_output_loss: 0.0095 - loss: 0.2022 - segmentation_output_accuracy: 0.9163 - segmentation_output_binary_dice_coefficient: 0.7314 - segmentation_output_loss: 0.1974
# Epoch 13/40
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 38s 205ms/step - classification_output_accuracy: 0.9911 - classification_output_loss: 0.0090 - loss: 0.1920 - segmentation_output_accuracy: 0.9207 - segmentation_output_binary_dice_coefficient: 0.7522 - segmentation_output_loss: 0.1875
# Epoch 14/40
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 38s 209ms/step - classification_output_accuracy: 0.9911 - classification_output_loss: 0.0114 - loss: 0.1942 - segmentation_output_accuracy: 0.9203 - segmentation_output_binary_dice_coefficient: 0.7517 - segmentation_output_loss: 0.1885
# Epoch 15/40
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 39s 215ms/step - classification_output_accuracy: 0.9887 - classification_output_loss: 0.0130 - loss: 0.1965 - segmentation_output_accuracy: 0.9210 - segmentation_output_binary_dice_coefficient: 0.7558 - segmentation_output_loss: 0.1900
# Epoch 16/40
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 39s 210ms/step - classification_output_accuracy: 0.9907 - classification_output_loss: 0.0098 - loss: 0.1775 - segmentation_output_accuracy: 0.9284 - segmentation_output_binary_dice_coefficient: 0.7720 - segmentation_output_loss: 0.1726
# Epoch 17/40
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 39s 214ms/step - classification_output_accuracy: 0.9866 - classification_output_loss: 0.0171 - loss: 0.1777 - segmentation_output_accuracy: 0.9299 - segmentation_output_binary_dice_coefficient: 0.7744 - segmentation_output_loss: 0.1692
# Epoch 18/40
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 39s 211ms/step - classification_output_accuracy: 0.9864 - classification_output_loss: 0.0131 - loss: 0.1747 - segmentation_output_accuracy: 0.9306 - segmentation_output_binary_dice_coefficient: 0.7822 - segmentation_output_loss: 0.1681
# Epoch 19/40
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 38s 208ms/step - classification_output_accuracy: 0.9908 - classification_output_loss: 0.0100 - loss: 0.1697 - segmentation_output_accuracy: 0.9323 - segmentation_output_binary_dice_coefficient: 0.7881 - segmentation_output_loss: 0.1647
# Epoch 20/40
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 38s 208ms/step - classification_output_accuracy: 0.9912 - classification_output_loss: 0.0068 - loss: 0.1455 - segmentation_output_accuracy: 0.9430 - segmentation_output_binary_dice_coefficient: 0.8106 - segmentation_output_loss: 0.1421
# Epoch 21/40
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 38s 209ms/step - classification_output_accuracy: 0.9927 - classification_output_loss: 0.0081 - loss: 0.1448 - segmentation_output_accuracy: 0.9425 - segmentation_output_binary_dice_coefficient: 0.8202 - segmentation_output_loss: 0.1407
# Epoch 22/40
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 39s 211ms/step - classification_output_accuracy: 0.9894 - classification_output_loss: 0.0118 - loss: 0.1434 - segmentation_output_accuracy: 0.9443 - segmentation_output_binary_dice_coefficient: 0.8204 - segmentation_output_loss: 0.1375
# Epoch 23/40
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 38s 208ms/step - classification_output_accuracy: 0.9871 - classification_output_loss: 0.0110 - loss: 0.1450 - segmentation_output_accuracy: 0.9433 - segmentation_output_binary_dice_coefficient: 0.8165 - segmentation_output_loss: 0.1395
# Epoch 24/40
# 118/183 ━━━━━━━━━━━━━━━━━━━━ 13s 207ms/step - classification_output_accuracy: 0.9855 - classification_output_loss: 0.0159 - loss: 0.1420 - segmentation_output_accuracy: 0.9458 - segmentation_output_binary_dice_coefficient: 0.8243 - segmentation_output_loss: 0.1341
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-e58c58ffa1c9> in <cell line: 0>()
# ----> 1 h_with_bn= backbone_model.fit(train_dataset, epochs=40)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369                 for step, iterator in epoch_iterator:
#     370                     callbacks.on_train_batch_begin(step)
# --> 371                     logs = self.train_function(iterator)
#     372                     callbacks.on_train_batch_end(step, logs)
#     373                     if self.stop_training:
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     218             ):
#     219                 opt_outputs = multi_step_on_iterator(iterator)
# --> 220                 if not opt_outputs.has_value():
#     221                     raise StopIteration
#     222                 return opt_outputs.get_value()
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/data/ops/optional_ops.py in has_value(self, name)
#     174   def has_value(self, name=None):
#     175     with ops.colocate_with(self._variant_tensor):
# --> 176       return gen_optional_ops.optional_has_value(
#     177           self._variant_tensor, name=name
#     178       )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/gen_optional_ops.py in optional_has_value(optional, name)
#     170   if tld.is_eager:
#     171     try:
# --> 172       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     173         _ctx, "OptionalHasValue", name, optional)
#     174       return _result
#
# KeyboardInterrupt:

# %%
backbone_model.evaluate(val_dataset)
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 378ms/step - classification_output_accuracy: 0.6692 - classification_output_loss: 0.4497 - loss: 1.1448 - segmentation_output_accuracy: 0.7726 - segmentation_output_binary_dice_coefficient: 0.4422 - segmentation_output_loss: 0.9199
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# [1.1564478874206543,
#  0.8964262008666992,
#  0.516542911529541,
#  0.6555299758911133,
#  0.7758695483207703,
#  0.4052949845790863]

# %%
backbone_model.save("fine_tuned_mobilenetv2.keras")

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(backbone_model)
tflite_model = converter.convert()
with open('fine_tuned_mobilenetv2.tflite', 'wb') as f:
    f.write(tflite_model)

# %% [markdown]
# ## Keeping same size

# %% [markdown]
# ## 512x512

# %%
# !gdown 1aWNF8y4pBFBok6Pbug5aszC9ox_WVKMo # 150 peer samples val
# !gdown 14RBBexZP7OqMD6z7YjsmliHe155q4eTC # 1000 peer samples train
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1aWNF8y4pBFBok6Pbug5aszC9ox_WVKMo
# From (redirected): https://drive.google.com/uc?id=1aWNF8y4pBFBok6Pbug5aszC9ox_WVKMo&confirm=t&uuid=8789b2f1-30eb-4fb6-8976-2be8bc194aa0
# To: /content/val.zip
# 100% 732M/732M [00:10<00:00, 71.4MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=14RBBexZP7OqMD6z7YjsmliHe155q4eTC
# From (redirected): https://drive.google.com/uc?id=14RBBexZP7OqMD6z7YjsmliHe155q4eTC&confirm=t&uuid=6b7e1d67-4a71-4d9c-8b5f-62701b23a18b
# To: /content/train.zip
# 100% 4.97G/4.97G [01:58<00:00, 42.1MB/s]

# %%
# !unzip train >> /dev/null
# !unzip val >> /dev/null

# %%
def separable_residual_block(input_tensor, num_filters, kernel_size=3):
    x = layers.SeparableConv2D(num_filters, (kernel_size, kernel_size), padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.SeparableConv2D(num_filters, (kernel_size, kernel_size), padding='same')(x)
    x = layers.BatchNormalization()(x)

    if input_tensor.shape[-1] != num_filters:
        input_tensor = layers.Conv2D(num_filters, (1, 1))(input_tensor)

    x = layers.add([x, input_tensor])
    x = layers.Activation('relu')(x)
    return x

def lite_encoder_block(input_tensor, num_filters, dropout_rate=0.1):
    x = layers.SeparableConv2D(num_filters, (3, 3), padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    if dropout_rate > 0:
        x = layers.SpatialDropout2D(dropout_rate)(x)

    p = layers.MaxPooling2D((2, 2))(x)
    return x, p

def lite_decoder_block(input_tensor, skip_features, num_filters, dropout_rate=0.1):
    x = layers.Conv2DTranspose(num_filters, (3, 3), strides=(2, 2), padding='same')(input_tensor)

    # Ensure compatible shapes for concatenation
    if x.shape[1] != skip_features.shape[1] or x.shape[2] != skip_features.shape[2]:
        x = layers.Resizing(skip_features.shape[1], skip_features.shape[2])(x)

    # Concatenate skip features
    x = layers.concatenate([x, skip_features], axis=-1)

    # Reduce parameter count with separable convolution
    x = layers.SeparableConv2D(num_filters, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    if dropout_rate > 0:
        x = layers.SpatialDropout2D(dropout_rate)(x)
    return x

def build_optimized_multi_task_unet_512(
    input_shape,
    num_classes,
    filters_base=16,  # Reduced base filters to manage memory for 512x512
    dropout_rate=0.1,
    final_activation='sigmoid'
):
    inputs = layers.Input(shape=input_shape)

    # Initial convolution - using standard conv for better feature extraction at start
    x = layers.Conv2D(filters_base, (3, 3), padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    # Encoder Path - 5 levels for 512x512 (vs 4 levels for 256x256)
    # Level 1: 512x512 -> 256x256
    s1, p1 = lite_encoder_block(x, filters_base, dropout_rate)

    # Level 2: 256x256 -> 128x128
    s2, p2 = lite_encoder_block(p1, filters_base*2, dropout_rate)

    # Level 3: 128x128 -> 64x64
    s3, p3 = lite_encoder_block(p2, filters_base*4, dropout_rate)

    # Level 4: 64x64 -> 32x32
    s4, p4 = lite_encoder_block(p3, filters_base*8, dropout_rate)

    # Level 5: 32x32 -> 16x16 (NEW LEVEL)
    s5, p5 = lite_encoder_block(p4, filters_base*16, dropout_rate)

    # Bottleneck at 16x16 - use separable residual block for performance
    bottleneck = separable_residual_block(p5, filters_base*32)  # Increased filters for bottleneck
    bottleneck = layers.SpatialDropout2D(dropout_rate*2)(bottleneck)

    # Decoder Path for Segmentation - 5 levels to match encoder
    # Level 5: 16x16 -> 32x32 (NEW LEVEL)
    d1 = lite_decoder_block(bottleneck, s5, filters_base*16, dropout_rate)

    # Level 4: 32x32 -> 64x64
    d2 = lite_decoder_block(d1, s4, filters_base*8, dropout_rate)

    # Level 3: 64x64 -> 128x128
    d3 = lite_decoder_block(d2, s3, filters_base*4, dropout_rate)

    # Level 2: 128x128 -> 256x256
    d4 = lite_decoder_block(d3, s2, filters_base*2, dropout_rate)

    # Level 1: 256x256 -> 512x512
    d5 = lite_decoder_block(d4, s1, filters_base, dropout_rate)

    # Segmentation Output at 512x512
    segmentation_output = layers.Conv2D(1, (1, 1))(d5)
    segmentation_output = layers.Activation(final_activation, name='segmentation_output')(segmentation_output)

    # Classification branch - using bottleneck features
    avg_pool = layers.GlobalAveragePooling2D()(bottleneck)
    max_pool = layers.GlobalMaxPooling2D()(bottleneck)
    pooled_features = layers.concatenate([avg_pool, max_pool])

    # Streamlined classification head
    classification_branch = layers.Dense(128)(pooled_features)
    classification_branch = layers.BatchNormalization()(classification_branch)
    classification_branch = layers.Activation('relu')(classification_branch)
    classification_branch = layers.Dropout(0.2)(classification_branch)

    # Classification Output
    classification_output = layers.Dense(num_classes, activation='softmax', name='classification_output')(classification_branch)

    model = Model(inputs=inputs, outputs=[classification_output, segmentation_output], name='Optimized_MultiTask_UNet_512')

    return model

def compile_model(model):
    losses = {
        'segmentation_output': 'binary_crossentropy',
        'classification_output': 'binary_crossentropy'
    }

    loss_weights = {
        'segmentation_output': 1.0,
        'classification_output': 0.5
    }

    metrics = {
        'segmentation_output': [binary_dice_coefficient, tf.keras.metrics.MeanIoU(num_classes=2)],
        'classification_output': ['accuracy']
    }

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss=losses,
        loss_weights=loss_weights,
        metrics=metrics
    )

    return model

# For 512x512 single-channel input (like NDVI)

model = build_optimized_multi_task_unet_512(
    input_shape=(512, 512, 1),
    num_classes=6,  # Your 6 anomaly classes
    filters_base=16,  # Reduced to manage memory
    dropout_rate=0.1
)
model = compile_model(model)
model.summary()

# %%
train_dataset, val_dataset = create_datasets(working_path=".", batch_size=32, export_type="NDVI", input_shape=(512, 512, 1))

model.fit(train_dataset, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 316s 1s/step - classification_output_accuracy: 0.2206 - classification_output_loss: 0.5531 - loss: 0.8449 - segmentation_output_accuracy: 0.7418 - segmentation_output_binary_dice_coefficient: 0.2647 - segmentation_output_loss: 0.5684
# Epoch 2/10
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 203s 1s/step - classification_output_accuracy: 0.3881 - classification_output_loss: 0.4073 - loss: 0.7294 - segmentation_output_accuracy: 0.7735 - segmentation_output_binary_dice_coefficient: 0.2551 - segmentation_output_loss: 0.5258
# Epoch 3/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step - classification_output_accuracy: 0.4342 - classification_output_loss: 0.3854 - loss: 0.7186 - segmentation_output_accuracy: 0.7717 - segmentation_output_binary_dice_coefficient: 0.2571 - segmentation_output_loss: 0.5259
# Epoch 4/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step - classification_output_accuracy: 0.4746 - classification_output_loss: 0.3615 - loss: 0.7014 - segmentation_output_accuracy: 0.7727 - segmentation_output_binary_dice_coefficient: 0.2592 - segmentation_output_loss: 0.5206
# Epoch 5/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 204s 1s/step - classification_output_accuracy: 0.5049 - classification_output_loss: 0.3471 - loss: 0.6905 - segmentation_output_accuracy: 0.7739 - segmentation_output_binary_dice_coefficient: 0.2662 - segmentation_output_loss: 0.5169
# Epoch 6/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - classification_output_accuracy: 0.5335 - classification_output_loss: 0.3335 - loss: 0.6757 - segmentation_output_accuracy: 0.7772 - segmentation_output_binary_dice_coefficient: 0.2718 - segmentation_output_loss: 0.5089
# Epoch 7/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 197s 1s/step - classification_output_accuracy: 0.5406 - classification_output_loss: 0.3201 - loss: 0.6662 - segmentation_output_accuracy: 0.7757 - segmentation_output_binary_dice_coefficient: 0.2799 - segmentation_output_loss: 0.5061
# Epoch 8/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 218s 1s/step - classification_output_accuracy: 0.5570 - classification_output_loss: 0.3183 - loss: 0.6622 - segmentation_output_accuracy: 0.7806 - segmentation_output_binary_dice_coefficient: 0.2762 - segmentation_output_loss: 0.5030
# Epoch 9/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 211s 1s/step - classification_output_accuracy: 0.5622 - classification_output_loss: 0.3156 - loss: 0.6525 - segmentation_output_accuracy: 0.7833 - segmentation_output_binary_dice_coefficient: 0.2815 - segmentation_output_loss: 0.4947
# Epoch 10/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 211s 1s/step - classification_output_accuracy: 0.5993 - classification_output_loss: 0.2979 - loss: 0.6480 - segmentation_output_accuracy: 0.7802 - segmentation_output_binary_dice_coefficient: 0.2929 - segmentation_output_loss: 0.4991

# %%
import tensorflow.keras.applications as keras_applications

def separable_residual_block(input_tensor, num_filters, kernel_size=3):
    """Lightweight residual block using separable convolutions"""
    x = layers.SeparableConv2D(num_filters, (kernel_size, kernel_size), padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.SeparableConv2D(num_filters, (kernel_size, kernel_size), padding='same')(x)
    x = layers.BatchNormalization()(x)


    if input_tensor.shape[-1] != num_filters:
        input_tensor = layers.Conv2D(num_filters, (1, 1))(input_tensor)

    x = layers.add([x, input_tensor])
    x = layers.Activation('relu')(x)
    return x

def lite_encoder_block(input_tensor, num_filters, dropout_rate=0.1):
    """Lightweight encoder block"""
    x = layers.SeparableConv2D(num_filters, (3, 3), padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    if dropout_rate > 0:
        x = layers.SpatialDropout2D(dropout_rate)(x)

    p = layers.MaxPooling2D((2, 2))(x)
    return x, p

def lite_decoder_block(input_tensor, skip_features, num_filters, dropout_rate=0.1):
    """Lightweight decoder block"""
    x = layers.Conv2DTranspose(num_filters, (3, 3), strides=(2, 2), padding='same')(input_tensor)


    if x.shape[1] != skip_features.shape[1] or x.shape[2] != skip_features.shape[2]:
        x = layers.Resizing(skip_features.shape[1], skip_features.shape[2])(x)


    x = layers.concatenate([x, skip_features], axis=-1)


    x = layers.SeparableConv2D(num_filters, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    if dropout_rate > 0:
        x = layers.SpatialDropout2D(dropout_rate)(x)
    return x

def binary_dice_coefficient(y_true, y_pred):
    """Binary Dice coefficient metric"""
    smooth = 1.0
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + smooth)

def get_backbone(backbone_name, input_tensor, weights='imagenet', trainable=False):
    backbone_dict = {
        'mobilenetv2': {
            'model': keras_applications.MobileNetV2,

            'skip_layers': ['block_16_expand_relu',
                           'block_13_expand_relu',
                           'block_6_expand_relu',
                           'block_3_expand_relu',
                           'block_1_expand_relu']
        }
    }

    if backbone_name.lower() not in backbone_dict:
        raise ValueError(f"Backbone {backbone_name} not supported. Choose from: {list(backbone_dict.keys())}")

    backbone_fn = backbone_dict[backbone_name.lower()]['model']
    skip_layer_names = backbone_dict[backbone_name.lower()]['skip_layers']

    backbone = backbone_fn(
        include_top=False,
        weights=weights,
        input_tensor=input_tensor,
        input_shape=None if input_tensor is not None else input_tensor.shape[1:]
    )

    backbone.trainable = trainable

    skip_connections = [backbone.get_layer(layer_name).output for layer_name in skip_layer_names]

    initial_features = input_tensor

    return backbone, skip_connections, initial_features

def build_backbone_multi_task_unet_512(
    input_shape,
    num_classes,
    backbone_name='mobilenetv2',
    backbone_trainable=False,
    filters_base=16,
    dropout_rate=0.1,
    final_activation='sigmoid'
):

    inputs = layers.Input(shape=input_shape)

    backbone, skip_features, initial_features = get_backbone(
        backbone_name=backbone_name,
        input_tensor=inputs,
        trainable=backbone_trainable
    )

    bottleneck = backbone.output

    bottleneck = separable_residual_block(bottleneck, filters_base*16)
    bottleneck = layers.SpatialDropout2D(dropout_rate*2)(bottleneck)

    d1 = lite_decoder_block(bottleneck, skip_features[0], filters_base*16, dropout_rate)

    d2 = lite_decoder_block(d1, skip_features[1], filters_base*8, dropout_rate)

    d3 = lite_decoder_block(d2, skip_features[2], filters_base*4, dropout_rate)

    d4 = lite_decoder_block(d3, skip_features[3], filters_base*2, dropout_rate)

    d5 = lite_decoder_block(d4, skip_features[4], filters_base, dropout_rate)

    d6 = lite_decoder_block(d5, initial_features, filters_base, dropout_rate)

    segmentation_output = layers.Conv2D(1, (1, 1))(d6)
    segmentation_output = layers.Activation(final_activation, name='segmentation_output')(segmentation_output)


    avg_pool = layers.GlobalAveragePooling2D()(bottleneck)
    max_pool = layers.GlobalMaxPooling2D()(bottleneck)
    pooled_features = layers.concatenate([avg_pool, max_pool])


    classification_branch = layers.Dense(128)(pooled_features)
    classification_branch = layers.BatchNormalization()(classification_branch)
    classification_branch = layers.Activation('relu')(classification_branch)
    classification_branch = layers.Dropout(0.2)(classification_branch)


    classification_output = layers.Dense(num_classes, activation='softmax', name='classification_output')(classification_branch)


    model = Model(inputs=inputs, outputs=[classification_output, segmentation_output],
                 name=f'Backbone_MultiTask_UNet_512_{backbone_name}')

    return model

def compile_model(model):
    losses = {
        'segmentation_output': 'binary_crossentropy',
        'classification_output': 'binary_crossentropy'
    }

    loss_weights = {
        'segmentation_output': 1.0,
        'classification_output': 0.5
    }

    metrics = {
        'segmentation_output': [binary_dice_coefficient, tf.keras.metrics.MeanIoU(num_classes=2)],
        'classification_output': ['accuracy']
    }

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss=losses,
        loss_weights=loss_weights,
        metrics=metrics
    )

    return model

input_shape = (512, 512, 3)
num_classes = 6

backbone_model_512 = build_backbone_multi_task_unet_512(
    input_shape,
    num_classes,
    backbone_name='mobilenetv2',
    backbone_trainable=False,
    filters_base=16,
    final_activation='sigmoid'
)
backbone_model_512 = compile_model(backbone_model_512)
# Out:
# <ipython-input-32-d4fc7c4e1bdf>:78: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   backbone = backbone_fn(

# %%
train_dataset, val_dataset = create_datasets(working_path=".", batch_size=32, export_type="RGB", input_shape=(512, 512, 3))

backbone_model_512.fit(train_dataset, epochs=10)
# Out:
# Epoch 1/10
#     182/Unknown 260s 1s/step - classification_output_accuracy: 0.3219 - classification_output_loss: 0.4978 - loss: 0.9272 - segmentation_output_binary_dice_coefficient: 0.2954 - segmentation_output_loss: 0.6783 - segmentation_output_mean_io_u_1: 0.3846
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 262s 1s/step - classification_output_accuracy: 0.3222 - classification_output_loss: 0.4974 - loss: 0.9266 - segmentation_output_binary_dice_coefficient: 0.2953 - segmentation_output_loss: 0.6779 - segmentation_output_mean_io_u_1: 0.3846
# Epoch 2/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 253s 1s/step - classification_output_accuracy: 0.6034 - classification_output_loss: 0.2959 - loss: 0.6493 - segmentation_output_binary_dice_coefficient: 0.2844 - segmentation_output_loss: 0.5013 - segmentation_output_mean_io_u_1: 0.3887
# Epoch 3/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 239s 1s/step - classification_output_accuracy: 0.7090 - classification_output_loss: 0.2307 - loss: 0.5877 - segmentation_output_binary_dice_coefficient: 0.3249 - segmentation_output_loss: 0.4724 - segmentation_output_mean_io_u_1: 0.3869
# Epoch 4/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 237s 1s/step - classification_output_accuracy: 0.7598 - classification_output_loss: 0.1929 - loss: 0.5629 - segmentation_output_binary_dice_coefficient: 0.3504 - segmentation_output_loss: 0.4665 - segmentation_output_mean_io_u_1: 0.3831
# Epoch 5/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 236s 1s/step - classification_output_accuracy: 0.8168 - classification_output_loss: 0.1583 - loss: 0.5199 - segmentation_output_binary_dice_coefficient: 0.3566 - segmentation_output_loss: 0.4408 - segmentation_output_mean_io_u_1: 0.3886
# Epoch 6/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 235s 1s/step - classification_output_accuracy: 0.8560 - classification_output_loss: 0.1291 - loss: 0.4961 - segmentation_output_binary_dice_coefficient: 0.3811 - segmentation_output_loss: 0.4315 - segmentation_output_mean_io_u_1: 0.3867
# Epoch 7/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 236s 1s/step - classification_output_accuracy: 0.8918 - classification_output_loss: 0.1051 - loss: 0.4797 - segmentation_output_binary_dice_coefficient: 0.4038 - segmentation_output_loss: 0.4272 - segmentation_output_mean_io_u_1: 0.3831
# Epoch 8/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 233s 1s/step - classification_output_accuracy: 0.9228 - classification_output_loss: 0.0771 - loss: 0.4516 - segmentation_output_binary_dice_coefficient: 0.4061 - segmentation_output_loss: 0.4130 - segmentation_output_mean_io_u_1: 0.3863
# Epoch 9/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 234s 1s/step - classification_output_accuracy: 0.9384 - classification_output_loss: 0.0660 - loss: 0.4416 - segmentation_output_binary_dice_coefficient: 0.4302 - segmentation_output_loss: 0.4086 - segmentation_output_mean_io_u_1: 0.3830
# Epoch 10/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 231s 1s/step - classification_output_accuracy: 0.9453 - classification_output_loss: 0.0555 - loss: 0.4182 - segmentation_output_binary_dice_coefficient: 0.4282 - segmentation_output_loss: 0.3905 - segmentation_output_mean_io_u_1: 0.3896

# %%
backbone_model_512.fit(train_dataset, epochs=10)
# Out:
# Epoch 1/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 237s 1s/step - classification_output_accuracy: 0.9560 - classification_output_loss: 0.0454 - loss: 0.4077 - segmentation_output_binary_dice_coefficient: 0.4481 - segmentation_output_loss: 0.3850 - segmentation_output_mean_io_u_1: 0.3880
# Epoch 2/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 233s 1s/step - classification_output_accuracy: 0.9663 - classification_output_loss: 0.0364 - loss: 0.3863 - segmentation_output_binary_dice_coefficient: 0.4688 - segmentation_output_loss: 0.3681 - segmentation_output_mean_io_u_1: 0.3869
# Epoch 3/10
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 231s 1s/step - classification_output_accuracy: 0.9663 - classification_output_loss: 0.0351 - loss: 0.3823 - segmentation_output_binary_dice_coefficient: 0.4756 - segmentation_output_loss: 0.3648 - segmentation_output_mean_io_u_1: 0.3880
# Epoch 4/10
#  79/182 ━━━━━━━━━━━━━━━━━━━━ 2:07 1s/step - classification_output_accuracy: 0.9772 - classification_output_loss: 0.0281 - loss: 0.3798 - segmentation_output_binary_dice_coefficient: 0.4905 - segmentation_output_loss: 0.3657 - segmentation_output_mean_io_u_1: 0.3815
